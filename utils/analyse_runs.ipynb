# %%
import wandb
import pickle
import os
import tqdm
import numpy as np

def get_sorted_runs(project_name, entity=None, metric="val-losses/mean/pos_l2_final<0.01", cached_data={}):    
    api = wandb.Api()
    runs = api.runs(f"{entity}/{project_name}" if entity else project_name)
    
    run_data = []
    
    for run in tqdm.tqdm(runs):
        if not(len(run.config['tasks']) == 1 and run.config['tasks'][0] == 'stack_blocks'):
            continue
        
        if run.id in cached_data:
            metric_values = cached_data[run.id][metric]
        else:
            history = run.scan_history(keys=[metric], page_size=200000,)
            metric_values = [row.get(metric, 0) for row in history]
            cached_data[run.id] = {}
            cached_data[run.id][metric] = metric_values
            cached_data[run.id]["config"] = run.config
            cached_data[run.id]["name"] = run.config['name']
            cached_data[run.id]["metadata"] = run.metadata
            
        max_metric_value = np.percentile(metric_values, 95) if len(metric_values) > 0 else 0
        run_data.append((run, max_metric_value))
    
    with open(cache_file, "wb") as f:
        pickle.dump(cached_data, f)
    
    sorted_runs = sorted(run_data, key=lambda x: x[1], reverse=True)
    
    return sorted_runs

def get_config(run, cached_data={}):
    if run.id in cached_data:
        return cached_data[run.id]["config"]
    else:
        cached_data[run.id] = {
            "config": run.config
        }
        with open(cache_file, "wb") as f:
            pickle.dump(cached_data, f)
        return cached_data[run.id]["config"]

def get_gpu_count(run, cached_data={}):
    if run.id in cached_data:
        return cached_data[run.id]["metadata"].get("gpu_count", 1)
    else:
        gpu_count = run.metadata.get("gpu_count", 1)
        cached_data[run.id] = {
            "metadata": {
                "gpu_count": gpu_count
            }
        }
        with open(cache_file, "wb") as f:
            pickle.dump(cached_data, f)
        return gpu_count    


if __name__ == "__main__":
    project = "3d_diffuser_actor_debug"  # Change this
    entity = "felix-herrmann"  # Change this if applicable
    # run_ids = ["toyzo1d5"]  # Define specific run IDs to include
    run_ids = None  # Include all runs
    metric = "val-losses/mean/pos_l2_final<0.01"  # Change this
    cache_file = "wandb_cache.pkl"  # Change this if needed
    
    if os.path.exists(cache_file):
        with open(cache_file, "rb") as f:
            cached_data = pickle.load(f)
    else:
        cached_data = {}

    
    sorted_results = get_sorted_runs(project, entity, cached_data=cached_data)
    
    for run, value in sorted_results:
        config = get_config(run, cached_data=cached_data)
        gpu_count = get_gpu_count(run, cached_data=cached_data)

        B = config.get('batch_size', 1) * gpu_count
        RN = config.get('rot_noise', 0)
        PN = config.get('pos_noise', 0)
        PCDN = config.get('pcd_noise', 0)
        D = config.get('dropout', 0)
        RES = config.get('feature_res', 'res3')
        FPS = config.get('fps_subsampling_factor', 0)
        HP = config.get('gripper_history_as_points', 0)
        CD = config.get('use_center_distance', 1)
        CP = config.get('use_center_projection', 1)
        VP = config.get('use_vector_projection', 1)
        AC = config.get('add_center', 1)

        print(f"Max : {value},\t B={B:2}, RN={RN:.2f}, PN={PN:.2f}, PCDN={PCDN:.2f}, D={D}, RES={RES}, FPS={FPS:2}, HP={HP}, CD={CD}, CP={CP}, VP={VP}, AC={AC}, Run ID: {run.id}, Name: {run.config['name']}")
        print(f"{run.config['base_log_dir']}/{run.config['exp_log_dir']}/{run.config['run_log_dir']}")
        print()
# Out:
# 100%|██████████| 77/77 [00:00<00:00, 248.20it/s]
# Max : 0.9123025715351105,	 B=16, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 5, HP=0, CD=1, CP=1, VP=1, AC=1, Run ID: o806fh5g, Name: train_3d_diffuser_actor
# train_logs/2025.01.23/21.57.22_Actor_18Peract_100Demo_multitask/diffusion_multitask-C120-B4-lr1e-4-DI1-2-H3-DT100
#
# Max : 0.8871165037155151,	 B=24, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=1, CD=1, CP=1, VP=1, AC=1, Run ID: xyoyswx6, Name: train_point_attention_lang_enhanced
# train_logs/train_logs/2025.01.27/09.42.37_PointAttnLangEnhanced_18Peract_100Demo_multitask/pointattnlangenhanced_multitask-C120-B24-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-drop0.0-DS1.0-ADALN1-res3-fps1-HP1
#
# Max : 0.8870987296104431,	 B=24, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=1, CD=1, CP=1, VP=1, AC=1, Run ID: dayoc7vs, Name: train_point_attention_lang_enhanced
# train_logs/train_logs/2025.01.27/09.42.37_PointAttnLangEnhanced_18Peract_100Demo_multitask/pointattnlangenhanced_multitask-C120-B24-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-drop0.0-DS1.0-ADALN1-res3-fps1-HP1
#
# Max : 0.8869643539190293,	 B=24, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 5, HP=0, CD=1, CP=1, VP=1, AC=1, Run ID: 92ia6mxa, Name: train_3d_diffuser_actor
# train_logs/2025.01.31/21.45.30_ActorWoSAURSA_18Peract_100Demo_multitask/diffusion_multitask-C120-B24-lr1e-4-DI1-2-H3-DT100
#
# Max : 0.8827997446060181,	 B=16, RN=0.20, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=0, CD=1, CP=1, VP=1, AC=1, Run ID: svhqw7gn, Name: train_point_attention_lang_enhanced
# train_logs/train_logs/2025.01.27/09.42.37_PointAttnLangEnhanced_18Peract_100Demo_multitask/pointattnlangenhanced_multitask-C120-B16-lr1e-4-DI1-2-H3-DT100-RN0.2-PN0.0-drop0.0-DS1.0-ADALN1-res3-fps1-HP0
#
# Max : 0.8507236242294312,	 B= 8, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=0, CD=1, CP=1, VP=1, AC=1, Run ID: kq776tp0, Name: train_point_attention_lang_enhanced
# train_logs/2025.02.05/08.02.11_PointAttn/pointattn_stack_blocks-C120-B8-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps1-HP0-CD1-CP1-VP1-AC1-FTdirect
#
# Max : 0.8485976070165634,	 B= 8, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=0, CD=1, CP=1, VP=1, AC=1, Run ID: nk18bemv, Name: train_point_attention_lang_enhanced
# train_logs/2025.02.05/08.02.06_PointAttn/pointattn_stack_blocks-C120-B8-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps1-HP0-CD1-CP1-VP1-AC1-FTsiren
#
# Max : 0.8462956547737122,	 B= 8, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=0, CD=1, CP=1, VP=0, AC=1, Run ID: h23mar86, Name: train_point_attention_lang_enhanced
# train_logs/2025.02.05/08.00.52_PointAttn/pointattn_stack_blocks-C120-B8-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps1-HP0-CD1-CP1-VP0-AC1-FTsinusoid
#
# Max : 0.8442893743515014,	 B= 8, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=0, CD=1, CP=1, VP=1, AC=1, Run ID: gv3fcp9e, Name: train_point_attention_lang_enhanced
# train_logs/2025.02.05/15.40.36_PointAttn/pointattn_stack_blocks-C120-B8-lr1e-4-DI1-2-H3-DT10-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps1-HP0-CD1-CP1-VP1-AC1-FTsinusoid
#
# Max : 0.843948471546173,	 B= 8, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=0, CD=0, CP=1, VP=0, AC=1, Run ID: r8xhapv4, Name: train_point_attention_lang_enhanced
# train_logs/2025.02.05/08.01.07_PointAttn/pointattn_stack_blocks-C120-B8-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps1-HP0-CD0-CP1-VP0-AC1-FTsinusoid
#
# Max : 0.8385990262031555,	 B= 6, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=0, CD=0, CP=1, VP=0, AC=1, Run ID: toyzo1d5, Name: train_point_attention_lang_enhanced
# train_logs/2025.02.05/15.35.15_PointAttn/pointattn_stack_blocks-C120-B6-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps1-HP0-CD1-CP1-VP1-AC1-FTsinusoid
#
# Max : 0.8382990658283234,	 B= 6, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=0, CD=0, CP=1, VP=0, AC=1, Run ID: pbfdy3k8, Name: train_point_attention_lang_enhanced
# train_logs/2025.02.05/15.38.48_PointAttn/pointattn_stack_blocks-C120-B6-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps1-HP0-CD1-CP1-VP1-AC1-FTsinusoid
#
# Max : 0.8377588868141175,	 B=24, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=0, CD=1, CP=1, VP=1, AC=1, Run ID: 661wiguq, Name: train_point_attention_lang_enhanced
# train_logs/train_logs/2025.01.27/09.42.37_PointAttnLangEnhanced_18Peract_100Demo_multitask/pointattnlangenhanced_multitask-C120-B24-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-drop0.2-DS1.0-ADALN1-res3-fps1-HP0
#
# Max : 0.8372941493988036,	 B= 8, RN=0.00, PN=0.01, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=0, CD=1, CP=1, VP=1, AC=1, Run ID: 78zwgv0u, Name: train_point_attention_lang_enhanced
# train_logs/2025.02.05/08.01.41_PointAttn/pointattn_stack_blocks-C120-B8-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.01-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps1-HP0-CD1-CP1-VP1-AC1-FTsinusoid
#
# Max : 0.8316767513751984,	 B= 6, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=0, CD=1, CP=1, VP=1, AC=0, Run ID: 79j9r55g, Name: train_point_attention_lang_enhanced
# train_logs/2025.02.05/14.55.19_PointAttn/pointattn_stack_blocks-C120-B6-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps1-HP0-CD1-CP1-VP1-AC0-FTsinusoid
#
# Max : 0.8239824503660201,	 B= 8, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=0, CD=1, CP=1, VP=1, AC=1, Run ID: oah8nxha, Name: train_point_attention_lang_enhanced
# train_logs/2025.02.05/08.00.45_PointAttn/pointattn_stack_blocks-C120-B8-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps1-HP0-CD1-CP1-VP1-AC1-FTsinusoid
#
# Max : 0.8110897094011307,	 B=32, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 5, HP=0, CD=1, CP=1, VP=1, AC=1, Run ID: 1mma3c69, Name: train_point_attention
# train_logs/2025.01.23/19.22.05_PointAttn_18Peract_100Demo_multitask/pointattn_multitask-C120-B32-lr1e-4-DI1-2-H3-DT100
#
# Max : 0.794529914855957,	 B=24, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=0, CD=1, CP=1, VP=1, AC=1, Run ID: 8xigqiwq, Name: train_point_attention_lang_enhanced
# train_logs/train_logs/2025.01.27/09.42.37_PointAttnLangEnhanced_18Peract_100Demo_multitask/pointattnlangenhanced_multitask-C120-B24-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-drop0.2-DS1.0-ADALN1-res3-fps1-HP0
#
# Max : 0.7919273138046264,	 B=24, RN=0.00, PN=0.00, PCDN=0.01, D=0, RES=res3, FPS= 1, HP=0, CD=0, CP=1, VP=0, AC=1, Run ID: lrzz43zc, Name: train_point_attention_lang_enhanced
# train_logs/train_logs/2025.01.27/09.42.37_PointAttnLangEnhanced_18Peract_100Demo_multitask/pointattnlangenhanced_multitask-C120-B24-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.01-drop0.2-DS1.0-ADALN1-res3-fps1-HP0-CD0-CP1-VP0
#
# Max : 0.7894057512283325,	 B=16, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 0, HP=0, CD=1, CP=1, VP=1, AC=1, Run ID: nz2m3s0r, Name: train_point_attention
# train_logs/2025.01.25/21.35.02_PointAttn_18Peract_100Demo_multitask/pointattn_multitask-C120-B16-lr1e-4-DI1-2-H3-DT100
#
# Max : 0.7553763151168822,	 B= 6, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=0, CD=1, CP=1, VP=1, AC=0, Run ID: ef9axwdl, Name: train_point_attention_lang_enhanced
# train_logs/2025.02.07/15.21.45_PointAttn/pointattn_stack_blocks-C120-B6-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps1-HP0-CD1-CP1-VP1-AC0-FTsinusoid
#
# Max : 0.7418333411216735,	 B=24, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 5, HP=0, CD=1, CP=1, VP=1, AC=1, Run ID: ed9wh539, Name: train_3d_diffuser_actor
# train_logs/2025.01.31/21.44.59_ActorWoSA_18Peract_100Demo_multitask/diffusion_multitask-C120-B24-lr1e-4-DI1-2-H3-DT100
#
# Max : 0.7303812503814696,	 B=32, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 5, HP=1, CD=0, CP=1, VP=0, AC=1, Run ID: glhxlfux, Name: train_point_attention_self_attn
# train_logs/2025.02.18/23.49.40_PointAttnSelfAttn_18Peract_100Demo_multitask/pointattn_sa_stack_blocks-C120-B32-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps5-HP1-CD0-CP1-VP0-AC1-FTsinusoid
#
# Max : 0.7296512275934219,	 B= 6, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=0, CD=1, CP=1, VP=1, AC=0, Run ID: hcmwot0m, Name: train_point_attention_lang_enhanced
# train_logs/2025.02.08/15.27.45_PointAttn/pointattn_stack_blocks-C120-B6-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps1-HP0-CD1-CP1-VP1-AC0-FTsinusoid
#
# Max : 0.6979198664426803,	 B=32, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 5, HP=1, CD=0, CP=1, VP=0, AC=1, Run ID: i7t8h9wa, Name: train_point_attention_self_attn
# train_logs/2025.02.18/23.52.21_PointAttnSelfAttn_18Peract_100Demo_multitask/pointattn_sa_stack_blocks-C120-B32-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps5-HP1-CD0-CP1-VP0-AC1-FTsinusoid
#
# Max : 0.6725572288036346,	 B= 6, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=0, CD=1, CP=1, VP=1, AC=0, Run ID: g1l93mk0, Name: train_point_attention_lang_enhanced
# train_logs/2025.02.06/15.21.14_PointAttn/pointattn_stack_blocks-C120-B6-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps1-HP0-CD1-CP1-VP1-AC0-FTsinusoid
#
# Max : 0.6193055659532547,	 B= 6, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS=10, HP=0, CD=1, CP=1, VP=1, AC=1, Run ID: 8f5dzvi6, Name: train_point_attention_self_attn
# train_logs/2025.01.26/13.04.24_PointAttnSelfAttn_18Peract_100Demo_multitask/pointattn_sa_multitask-C120-B6-lr1e-4-DI1-2-H3-DT100
#
# Max : 0.5977339327335357,	 B=32, RN=0.00, PN=0.00, PCDN=0.05, D=0, RES=res3, FPS= 5, HP=1, CD=0, CP=1, VP=0, AC=1, Run ID: q33tdsds, Name: train_point_attention_self_attn
# train_logs/2025.02.18/23.51.11_PointAttnSelfAttn_18Peract_100Demo_multitask/pointattn_sa_stack_blocks-C120-B32-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.05-drop0.0-DS1.0-ADALN1-res3-fps5-HP1-CD0-CP1-VP0-AC1-FTsinusoid
#
# Max : 0.5976686477661133,	 B= 6, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=0, CD=1, CP=1, VP=1, AC=0, Run ID: xoit3lo5, Name: train_point_attention_lang_enhanced
# train_logs/2025.02.05/15.21.13_PointAttn/pointattn_stack_blocks-C120-B6-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps1-HP0-CD1-CP1-VP1-AC0-FTsinusoid
#
# Max : 0.47325572371482844,	 B=32, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 5, HP=0, CD=1, CP=1, VP=1, AC=1, Run ID: u94ersh7, Name: train_point_attention_self_attn
# train_logs/2025.02.18/23.56.36_PointAttnSelfAttn_18Peract_100Demo_multitask/pointattn_sa_stack_blocks-C120-B32-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps5-HP0-CD1-CP1-VP1-AC1-FTsinusoid
#
# Max : 0.4500877559185027,	 B=32, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 5, HP=1, CD=1, CP=1, VP=1, AC=1, Run ID: 825pnzng, Name: train_point_attention_self_attn
# train_logs/2025.02.19/00.01.34_PointAttnSelfAttn_18Peract_100Demo_multitask/pointattn_sa_stack_blocks-C120-B32-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps5-HP1-CD1-CP1-VP1-AC1-FTsinusoid
#
# Max : 0.2780303210020061,	 B=32, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 5, HP=1, CD=1, CP=1, VP=0, AC=1, Run ID: taa8hi99, Name: train_point_attention_self_attn
# train_logs/2025.02.19/08.00.15_PointAttnSelfAttn_18Peract_100Demo_multitask/pointattn_sa_stack_blocks-C120-B32-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps5-HP1-CD1-CP1-VP0-AC1-FTsinusoid
#
# Max : 0.1069357596337795,	 B= 8, RN=0.00, PN=0.00, PCDN=0.01, D=0, RES=res3, FPS= 1, HP=0, CD=1, CP=1, VP=1, AC=1, Run ID: hxxwpoos, Name: train_point_attention_lang_enhanced
# train_logs/2025.02.05/08.01.28_PointAttn/pointattn_stack_blocks-C120-B8-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.01-drop0.0-DS1.0-ADALN1-res3-fps1-HP0-CD1-CP1-VP1-AC1-FTsinusoid
#
# Max : 0.0029761907644569874,	 B= 8, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 1, HP=0, CD=1, CP=0, VP=0, AC=1, Run ID: ewiu1ym0, Name: train_point_attention_lang_enhanced
# train_logs/2025.02.05/08.01.00_PointAttn/pointattn_stack_blocks-C120-B8-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps1-HP0-CD1-CP0-VP0-AC1-FTsinusoid
#
# Max : 0,	 B=32, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 5, HP=1, CD=0, CP=1, VP=0, AC=1, Run ID: disy6r6o, Name: train_point_attention_self_attn
# train_logs/2025.02.18/23.41.58_PointAttnSelfAttn_18Peract_100Demo_multitask/pointattn_sa_stack_blocks-C120-B32-lr1e-4-DI1-2-H3-DT100-RN0.0-PN0.0-PCDN0.0-drop0.0-DS1.0-ADALN1-res3-fps5-HP1-CD0-CP1-VP0-AC1-FTsinusoid
#
# Max : 0.0,	 B=24, RN=0.00, PN=0.00, PCDN=0.00, D=0, RES=res3, FPS= 5, HP=0, CD=1, CP=1, VP=1, AC=1, Run ID: l8kd18c8, Name: train_3d_diffuser_actor
# train_logs/2025.01.31/21.45.56_ActorFM_18Peract_100Demo_multitask/diffusionFM_multitask-C120-B24-lr1e-4-DI1-2-H3-DT100
